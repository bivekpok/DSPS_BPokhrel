# %% [markdown]
# <a href="https://colab.research.google.com/github/bivekpok/DSPS_BPokhrel/blob/main/HW4_5/HW4_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pylab as pl
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from scipy.optimize import minimize

# %%
grbAG = pd.read_csv('https://raw.githubusercontent.com/fedhere/DSPS_FBianco/main/data/grb050525A.csv')

# %%
grbAG.head()
# Out:
#   filter  time    mag  magerr  upperlimit
# 0      V    66  13.21    0.24           0
# 1      V    67  12.90    0.23           0
# 2      V    68  12.86    0.23           0
# 3      V    69  13.01    0.23           0
# 4      V    70  12.97    0.23           0

# %%
grbAG.tail()
# Out:
#     filter     time    mag  magerr  upperlimit
# 114     W1    63738  21.20     NaN           1
# 115     M2    74798  21.59     NaN           1
# 116      U   128928  20.05     NaN           1
# 117      V   971360  22.09     NaN           1
# 118      V  1171176  21.16     NaN           1

# %%
#create a figure container and an axis object inside of it
ax = pl.figure(figsize=(10,10)).add_subplot(111)

#loop on every filter to plot - this will give differnt colors naturally.
#Use pl.errorbar to plot the uncertainties

for f in grbAG["filter"].unique():
    pl.errorbar(grbAG.loc[grbAG["filter"] == f, "time"],
                grbAG.loc[grbAG["filter"] == f, "mag"],
                yerr=grbAG.loc[grbAG["filter"] == f, "magerr"],
                fmt='.', ms=0,
                fcolor=None, label=None)

# replot to add a better marker (optional)
for f in grbAG["filter"].unique():
    pl.scatter(grbAG.loc[grbAG["filter"] == f, "time"],
               grbAG.loc[grbAG["filter"] == f, "mag"],
               alpha=1, s=100, linewidth=2,
               label=f,
               edgecolor='#cccccc')


# plot the upperlimits as arrows
nuplim = grbAG.mag.isna().sum()
for i in grbAG[grbAG.upperlimit == 1].index:
    pl.arrow(grbAG.loc[i].time,
             grbAG.loc[i].magerr, 0, 2,
            head_width=0.05, head_length=0.1, ec='k')

# I am going to invert the y axis because the "magnitude" measurement is an inverse scale: brighter is smaller
pl.ylim(24,11.7)
pl.legend()

#Always rememebr you axis labels!!
pl.ylabel("magnitude", fontsize=20)
pl.xlabel("time", fontsize=20);
pl.text(0.5, -0.1, 'plot with all x and y value with time and magg',
        transform=ax.transAxes, fontsize=12, horizontalalignment='center')
# Out:
# Text(0.5, -0.1, 'plot with all x and y value with time and magg')

# %%
#create a figure container and an axis object inside of it
ax = pl.figure(figsize=(10,10)).add_subplot(111)

#loop on every filter to plot - this will give differnt colors naturally.
#Use pl.errorbar to plot the uncertainties

for f in grbAG["filter"].unique():
    pl.errorbar(grbAG.loc[grbAG["filter"] == f, "time"],
                grbAG.loc[grbAG["filter"] == f, "mag"],
                yerr=grbAG.loc[grbAG["filter"] == f, "magerr"],
                fmt='.', ms=0,
                fcolor=None, label=None)

# replot to add a better marker (optional)
for f in grbAG["filter"].unique():
    pl.scatter(grbAG.loc[grbAG["filter"] == f, "time"],
               grbAG.loc[grbAG["filter"] == f, "mag"],
               alpha=1, s=100, linewidth=2,
               label=f,
               edgecolor='#cccccc')


# plot the upperlimits as arrows
nuplim = grbAG.mag.isna().sum()
for i in grbAG[grbAG.upperlimit == 1].index:
    pl.arrow(grbAG.loc[i].time,
             grbAG.loc[i].magerr, 0, 2,
            head_width=0.05, head_length=0.1, ec='k')

# I am going to invert the y axis because the "magnitude" measurement is an inverse scale: brighter is smaller
pl.ylim(24,11.7)
pl.legend()

#Always rememebr you axis labels!!
pl.ylabel("magnitude", fontsize=20)
pl.xlabel("log-time", fontsize=20)
pl.text(0.5, -0.1, 'plot with all x and y value with logtime and magg',
        transform=ax.transAxes, fontsize=12, horizontalalignment='center')

pl.xscale('log')

# %%
grbAG = grbAG[grbAG.upperlimit == 0]
grbAG['logtime'] = np.log10(grbAG['time'])
grbAG
# Out:
# <ipython-input-29-af88d76f8663>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grbAG['logtime'] = np.log10(grbAG['time'])
#     filter   time        mag  magerr  upperlimit   logtime
# 0        V     66  13.210000    0.24           0  1.819544
# 1        V     67  12.900000    0.23           0  1.826075
# 2        V     68  12.860000    0.23           0  1.832509
# 3        V     69  13.010000    0.23           0  1.838849
# 4        V     70  12.970000    0.23           0  1.845098
# ..     ...    ...        ...     ...         ...       ...
# 103      V  35638  18.860000    0.27           0  4.551913
# 104     M2  39683  20.369034    0.30           0  4.598604
# 105     W1  40585  21.017147    0.39           0  4.608366
# 106      U  41040  20.674538    0.54           0  4.613207
# 109     M2  51257  20.989034    0.48           0  4.709753
#
# [108 rows x 6 columns]

# %%
#create a figure container and an axis object inside of it
ax = pl.figure(figsize=(10,10)).add_subplot(111)

#loop on every filter to plot - this will give differnt colors naturally.
#Use pl.errorbar to plot the uncertainties

for f in grbAG["filter"].unique():
    pl.errorbar(grbAG.loc[grbAG["filter"] == f, "time"],
                grbAG.loc[grbAG["filter"] == f, "mag"],
                yerr=grbAG.loc[grbAG["filter"] == f, "magerr"],
                fmt='.', ms=0,
                fcolor=None, label=None)

# replot to add a better marker (optional)
for f in grbAG["filter"].unique():
    pl.scatter(grbAG.loc[grbAG["filter"] == f, "time"],
               grbAG.loc[grbAG["filter"] == f, "mag"],
               alpha=1, s=100, linewidth=2,
               label=f,
               edgecolor='#cccccc')


# plot the upperlimits as arrows
nuplim = grbAG.mag.isna().sum()
for i in grbAG[grbAG.upperlimit == 1].index:
    pl.arrow(grbAG.loc[i].time,
             grbAG.loc[i].magerr, 0, 2,
            head_width=0.05, head_length=0.1, ec='k')

# I am going to invert the y axis because the "magnitude" measurement is an inverse scale: brighter is smaller
pl.ylim(24,11.7)
pl.legend()

#Always rememebr you axis labels!!
pl.ylabel("magnitude", fontsize=20)
pl.xlabel("log-time", fontsize=20)
pl.text(0.5, -0.1, 'plot with all x and y value with logtime and magg',
        transform=ax.transAxes, fontsize=12, horizontalalignment='center')
pl.xscale('log')

# %%
 x = grbAG['logtime'].values
 X = np.c_[np.ones(len(x)),x]
 y = grbAG['mag'].values

 theta_best = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)
 theta_best
# Out:
# array([8.58266823, 2.51199984])

# %%
print(f' best value fit parameters from the normal/analytic equation are slope: {theta_best[1]:2f}, intercept: {theta_best[0]:2f}')
# Out:
#  best value fit parameters from the normal/analytic equation are slope: 2.512000, intercept: 8.582668

# %%
X = np.c_[np.ones(len(x)),x]
y =  y = grbAG['mag'].values
lr = LinearRegression()
par = lr.fit(X,y)

# %%
print(par.intercept_)
print(par.coef_)
print(f'the parameters are intercept: { par.intercept_:.2f} and slope:  { (par.coef_[1]):2f}')
# Out:
# 8.582668233648771
# [0.         2.51199984]
# the parameters are intercept: 8.58 and slope:  2.512000

# %%
# x0 = np.linspace(min(grbAG('logtime')), max(grbAG('logtime')), 1000)
# y0 = x*8.58266823 + 2.51199984
def line(slope, intercept, x):
   y = slope*x + intercept
   return y
def of(args, x, y):
    slope, intercept = args
    y0 = line(slope, intercept, x)
    f = abs(y - y0)
    return np.sum(f)
def of_l2(args, x, y):
    slope, intercept = args
    y0 = line(slope, intercept, x)
    f = (y - y0)**2
    return np.sum(f)
initial_guess = (10, 0.5)  # Provide initial guesses for slope and intercept
par = minimize(of, initial_guess, args=(x, y))
par_l2 = minimize(of_l2, initial_guess, args= (x, y))
print(f' the par : {par}')
print(f'the par_l2 : {par_l2}')
# Out:
#  the par :   message: Desired error not necessarily achieved due to precision loss.
#   success: False
#    status: 2
#       fun: 26.319228397308184
#         x: [ 2.633e+00  8.246e+00]
#       nit: 10
#       jac: [-1.958e+00  0.000e+00]
#  hess_inv: [[ 2.281e-03 -5.707e-03]
#             [-5.707e-03  1.479e-02]]
#      nfev: 201
#      njev: 66
# the par_l2 :   message: Optimization terminated successfully.
#   success: True
#    status: 0
#       fun: 12.825987500725509
#         x: [ 2.512e+00  8.583e+00]
#       nit: 5
#       jac: [-1.192e-07  1.192e-07]
#  hess_inv: [[ 7.114e-03 -2.030e-02]
#             [-2.030e-02  6.254e-02]]
#      nfev: 21
#      njev: 7

# %%
#create a figure container and an axis object inside of it
ax = pl.figure(figsize=(10,10)).add_subplot(111)

#loop on every filter to plot - this will give differnt colors naturally.
#Use pl.errorbar to plot the uncertainties

for f in grbAG["filter"].unique():
    pl.errorbar(grbAG.loc[grbAG["filter"] == f, "logtime"],
                grbAG.loc[grbAG["filter"] == f, "mag"],
                yerr=grbAG.loc[grbAG["filter"] == f, "magerr"],
                fmt='.', ms=0,
                fcolor=None, label=None)

# replot to add a better marker (optional)
for f in grbAG["filter"].unique():
    pl.scatter(grbAG.loc[grbAG["filter"] == f, "logtime"],
               grbAG.loc[grbAG["filter"] == f, "mag"],
               alpha=1, s=100, linewidth=2,
               label=f,
               edgecolor='#cccccc')


# plot the upperlimits as arrows
nuplim = grbAG.mag.isna().sum()
for i in grbAG[grbAG.upperlimit == 1].index:
    pl.arrow(grbAG.loc[i].logtime,
             grbAG.loc[i].magerr, 0, 2,
            head_width=0.05, head_length=0.1, ec='k')

# I am going to invert the y axis because the "magnitude" measurement is an inverse scale: brighter is smaller

pl.plot(x,line(par.x[0], par.x[1], x), label = "L1_optimization")

pl.plot(x, line(2.512000, 8.58, x), label = "linear regression")
#Always rememebr you axis labels!!
pl.ylabel("magnitude", fontsize=20)
pl.xlabel("log-time", fontsize=20)
pl.text(0.5, -0.1, 'plot with all x and y value, with function optimized using all x and all y scilearn.optimize fucntion with L1 norm',
        transform=ax.transAxes, fontsize=12, horizontalalignment='center')
# pl.xscale('log')
pl.ylim(24,11.7)
pl.legend()

# %%
#create a figure container and an axis object inside of it
ax = pl.figure(figsize=(10,10)).add_subplot(111)

#loop on every filter to plot - this will give differnt colors naturally.
#Use pl.errorbar to plot the uncertainties

for f in grbAG["filter"].unique():
    pl.errorbar(grbAG.loc[grbAG["filter"] == f, "logtime"],
                grbAG.loc[grbAG["filter"] == f, "mag"],
                yerr=grbAG.loc[grbAG["filter"] == f, "magerr"],
                fmt='.', ms=0,
                fcolor=None, label=None)

# replot to add a better marker (optional)
for f in grbAG["filter"].unique():
    pl.scatter(grbAG.loc[grbAG["filter"] == f, "logtime"],
               grbAG.loc[grbAG["filter"] == f, "mag"],
               alpha=1, s=100, linewidth=2,
               label=f,
               edgecolor='#cccccc')


# plot the upperlimits as arrows
nuplim = grbAG.mag.isna().sum()
for i in grbAG[grbAG.upperlimit == 1].index:
    pl.arrow(grbAG.loc[i].logtime,
             grbAG.loc[i].magerr, 0, 2,
            head_width=0.05, head_length=0.1, ec='k')

# I am going to invert the y axis because the "magnitude" measurement is an inverse scale: brighter is smaller

pl.plot(x,line(par_l2.x[0], par_l2.x[1], x), label = "L2_optimization")

pl.plot(x, line(2.512000, 8.58, x), label = "linear regression")
#Always rememebr you axis labels!!
pl.ylabel("magnitude", fontsize=20)
pl.xlabel("log-time", fontsize=20)
pl.text(0.5, -0.1, 'plot with all x and y value, with function optimized using all x and all y scilearn.optimize fucntion with L2 norm',
        transform=ax.transAxes, fontsize=12, horizontalalignment='center')
# pl.xscale('log')
pl.ylim(24,11.7)
pl.legend()

# %% [markdown]
# ## Using Sklearn to train test split the dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)
initial_guess = (10, 0.5)  # Provide initial guesses for slope and intercept
train_par = minimize(of, initial_guess, args=(X_train, y_train))
train_par_l2 = minimize(of_l2, initial_guess, args= (X_train, y_train))
print(f' the par : {train_par}')
print(f'the par_l2 : {train_par_l2}')
# Out:
#  the par :   message: Desired error not necessarily achieved due to precision loss.
#   success: False
#    status: 2
#       fun: 20.75709748846497
#         x: [ 2.567e+00  8.399e+00]
#       nit: 10
#       jac: [ 1.384e+00  1.834e-01]
#  hess_inv: [[ 1.540e-03 -1.640e-03]
#             [-1.640e-03  2.110e-03]]
#      nfev: 234
#      njev: 74
# the par_l2 :   message: Optimization terminated successfully.
#   success: True
#    status: 0
#       fun: 10.406886415354322
#         x: [ 2.484e+00  8.659e+00]
#       nit: 5
#       jac: [ 5.960e-07 -1.192e-07]
#  hess_inv: [[ 8.634e-03 -2.517e-02]
#             [-2.517e-02  7.956e-02]]
#      nfev: 21
#      njev: 7

# %%
#create a figure container and an axis object inside of it
ax = pl.figure(figsize=(10,10)).add_subplot(111)

#loop on every filter to plot - this will give differnt colors naturally.
#Use pl.errorbar to plot the uncertainties

for f in grbAG["filter"].unique():
    pl.errorbar(grbAG.loc[grbAG["filter"] == f, "logtime"],
                grbAG.loc[grbAG["filter"] == f, "mag"],
                yerr=grbAG.loc[grbAG["filter"] == f, "magerr"],
                fmt='.', ms=0,
                fcolor=None, label=None)

# replot to add a better marker (optional)
for f in grbAG["filter"].unique():
    pl.scatter(grbAG.loc[grbAG["filter"] == f, "logtime"],
               grbAG.loc[grbAG["filter"] == f, "mag"],
               alpha=1, s=100, linewidth=2,
               label=f,
               edgecolor='#cccccc')


# plot the upperlimits as arrows
nuplim = grbAG.mag.isna().sum()
for i in grbAG[grbAG.upperlimit == 1].index:
    pl.arrow(grbAG.loc[i].logtime,
             grbAG.loc[i].magerr, 0, 2,
            head_width=0.05, head_length=0.1, ec='k')

# I am going to invert the y axis because the "magnitude" measurement is an inverse scale: brighter is smaller

pl.plot(X_test,line(train_par_l2.x[0], train_par_l2.x[1], X_test), label = "L2_optimization_test ")

pl.plot(x, line(2.512000, 8.58, x), label = "linear regression")
#Always rememebr you axis labels!!
pl.ylabel("magnitude", fontsize=20)
pl.xlabel("log-time", fontsize=20)
pl.text(0.5, -0.1, 'plot with all x and y value, here X_test and y_test being tested against the function optimized using X_train and y_train using scilearn.optimize fucntion with L2 norm',
        transform=ax.transAxes, fontsize=12, horizontalalignment='center')
# pl.xscale('log')
pl.ylim(24,11.7)
pl.legend()

# %%
#create a figure container and an axis object inside of it
ax = pl.figure(figsize=(10,10)).add_subplot(111)

#loop on every filter to plot - this will give differnt colors naturally.
#Use pl.errorbar to plot the uncertainties

for f in grbAG["filter"].unique():
    pl.errorbar(grbAG.loc[grbAG["filter"] == f, "logtime"],
                grbAG.loc[grbAG["filter"] == f, "mag"],
                yerr=grbAG.loc[grbAG["filter"] == f, "magerr"],
                fmt='.', ms=0,
                fcolor=None, label=None)

# replot to add a better marker (optional)
for f in grbAG["filter"].unique():
    pl.scatter(grbAG.loc[grbAG["filter"] == f, "logtime"],
               grbAG.loc[grbAG["filter"] == f, "mag"],
               alpha=1, s=100, linewidth=2,
               label=f,
               edgecolor='#cccccc')


# plot the upperlimits as arrows
nuplim = grbAG.mag.isna().sum()
for i in grbAG[grbAG.upperlimit == 1].index:
    pl.arrow(grbAG.loc[i].time,
             grbAG.loc[i].magerr, 0, 2,
            head_width=0.05, head_length=0.1, ec='k')

# I am going to invert the y axis because the "magnitude" measurement is an inverse scale: brighter is smaller
# pl.plot(X_test, y_test)
pl.plot(X_test,line(train_par.x[0], train_par.x[1], X_test), label = "L1_optimization_test ")

pl.plot(x, line(2.512000, 8.58, x), label = "linear regression")
#Always rememebr you axis labels!!
pl.ylabel("magnitude", fontsize=20)
pl.xlabel("log-time", fontsize=20)
pl.text(0.5, -0.1, 'plot with all x and y value, here X_test and y_test being tested against the function optimized using X_train and y_train using scilearn.optimize fucntion with L1 norm',
        transform=ax.transAxes, fontsize=12, horizontalalignment='center')
# pl.xscale('log')
pl.ylim(24,11.7)
pl.legend()

# %%
ax = pl.figure(figsize=(10,10)).add_subplot(111)

pl.scatter(X_test, y_test, alpha=1, s=100, linewidth=2,
               label= 'test points',
               edgecolor='#cccccc')
pl.plot(X_test,line(train_par.x[0], train_par.x[1], X_test), label = "L1_optimization_test ", color ='red')

# pl.plot(x, line(2.512000, 8.58, x), label = "linear regression")
#Always rememebr you axis labels!!
pl.ylabel("magnitude", fontsize=20)
pl.xlabel("log-time", fontsize=20)
pl.text(0.5, -0.15, 'X_test and y_test being tested against the function optimized using X_train and y_train \n using scilearn.optimize fucntion with L1 norm',
        transform=ax.transAxes, fontsize=12, horizontalalignment='center')
# pl.xscale('log')
pl.ylim(24,11.7)
pl.legend()

# %%
ax = pl.figure(figsize=(10,10)).add_subplot(111)

pl.scatter(X_test, y_test, alpha=1, s=100, linewidth=2,
               label= 'test points',
               edgecolor='#cccccc')
pl.plot(X_test,line(train_par_l2.x[0], train_par_l2.x[1], X_test), label = "L1_optimization_test ", color ='red')

# pl.plot(x, line(2.512000, 8.58, x), label = "linear regression")
#Always rememebr you axis labels!!
pl.ylabel("magnitude", fontsize=20)
pl.xlabel("log-time", fontsize=20)
pl.text(0.5, -0.15, 'X_test and y_test being tested against the function optimized using X_train and y_train \n using scilearn.optimize fucntion with L2 norm',
        transform=ax.transAxes, fontsize=12, horizontalalignment='center')
# pl.xscale('log')
pl.ylim(24,11.7)
pl.legend()

# %%
 lr.score(X,y)
 X2_train, X2_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
 lr.score(X2_train, y_train)
# Out:
# 0.9715687013252898

# %%
print(f' Score for the whole set : { lr.score(X, y):.4f}')
print(f' Score for the train set : { lr.score(X2_train, y_train):.4f}')
print(f' Score for the test set : { lr.score(X2_test, y_test):.4f}')
# Out:
#  Score for the whole set : 0.9719
#  Score for the train set : 0.9716
#  Score for the test set : 0.9708
